# %%
import pandas as pd
from sodapy import Socrata
client = Socrata("www.datos.gov.co", None, timeout=100)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
query = """
SELECT DISTINCT nit_entidad, nombre_entidad, orden, sector, rama, entidad_centralizada, codigo_entidad
"""
results = client.get("jbjy-vk9h", query=query)

dim_entidades = pd.DataFrame.from_records(results)

dim_entidades = dim_entidades[[
     "nit_entidad", "nombre_entidad",
    "orden", "sector", "rama", "entidad_centralizada",
    "codigo_entidad"
]]

dim_entidades.head()
# Out:
#   nit_entidad                            nombre_entidad        orden  \
# 0     4653184  UNIDAD DE SERVICIOS PUBLICOS DE GUACHENE  Territorial
# 1     7180873           PERSONERIA MUNICIPAL DE INIRIDA  Territorial
# 2    40330032                            IVONNE LINARES     Nacional
# 3    51976852           Rosario Fernàndez de Soto Pombo  No Definido
# 4    52655227              MARIA BERENICE AGUIRRE GÓMEZ  No Definido
#
#                    sector                  rama entidad_centralizada  \
# 0  No aplica/No pertenece  Corporación Autónoma      Descentralizada
# 1  No aplica/No pertenece  Corporación Autónoma      Descentralizada
# 2        Servicio Público             Ejecutivo      Descentralizada
# 3             No Definido           No Definido         Centralizada
# 4             No Definido           No Definido         Centralizada
#
#   codigo_entidad
# 0      718762313
# 1      709951321
# 2      700894108
# 3      703242123
# 4      705919934

# %%
query = """
SELECT DISTINCT documento_proveedor, proveedor_adjudicado, tipodocproveedor, es_pyme, es_grupo
"""
results = client.get("jbjy-vk9h", query=query)

dim_proveedores = pd.DataFrame.from_records(results)

dim_proveedores = dim_proveedores[[
    "documento_proveedor", "proveedor_adjudicado",
    "tipodocproveedor", "es_pyme", "es_grupo"
]]

dim_proveedores.head()
# Out:
#   documento_proveedor         proveedor_adjudicado      tipodocproveedor  \
# 0                   -             CONSORCIO PCG GR                  Otro
# 1                   -  UT ACUEDUCTO ARBOLEDAS 2025  Cédula de Ciudadanía
# 2                   -          UT INTERHOSPITAL DC                  Otro
# 3                   -               UT PLACAS 2025                  Otro
# 4                 ---            CONSORCIO DARZI 1                  Otro
#
#   es_pyme es_grupo
# 0      No       Si
# 1      Si       Si
# 2      Si       Si
# 3      Si       Si
# 4      Si       Si

# %%
query = """
SELECT DISTINCT departamento, ciudad, localizaci_n
"""
results = client.get("jbjy-vk9h", query=query)

dim_geografia = pd.DataFrame.from_records(results)

dim_geografia = dim_geografia[[
     "departamento", "ciudad", "localizaci_n"
]]

dim_geografia.head()
# Out:
#   departamento       ciudad                                   localizaci_n
# 0     Amazonas      Leticia  Colombia, Departamento del Amazonas , Leticia
# 1     Amazonas  No Definido  Colombia, Departamento del Amazonas , Leticia
# 2    Antioquia    Abejorral              Colombia,  Antioquia ,  Abejorral
# 3    Antioquia   Alejandría             Colombia,  Antioquia ,  Alejandría
# 4    Antioquia        Amagá                  Colombia,  Antioquia ,  Amagá

# %%
query = """
SELECT DISTINCT tipo_de_contrato, modalidad_de_contratacion, justificacion_modalidad_de, codigo_de_categoria_principal
"""
results = client.get("jbjy-vk9h", query=query)

dim_tipo_contrato = pd.DataFrame.from_records(results)

dim_tipo_contrato = dim_tipo_contrato[[
    "tipo_de_contrato", "modalidad_de_contratacion",
    "justificacion_modalidad_de", "codigo_de_categoria_principal"
]]

dim_tipo_contrato.head()
# Out:
#          tipo_de_contrato      modalidad_de_contratacion  \
# 0  Acuerdo de cooperación  Contratación régimen especial
# 1  Acuerdo de cooperación  Contratación régimen especial
# 2  Acuerdo de cooperación  Contratación régimen especial
# 3  Acuerdo de cooperación  Contratación régimen especial
# 4  Acuerdo de cooperación  Contratación régimen especial
#
#   justificacion_modalidad_de codigo_de_categoria_principal
# 0            Regla aplicable                   UNSPECIFIED
# 1            Regla aplicable                   V1.43231507
# 2            Regla aplicable                   V1.80101500
# 3            Regla aplicable                   V1.80101600
# 4            Regla aplicable                   V1.80101604

# %%
query = """
SELECT DISTINCT fecha_de_firma, fecha_de_inicio_del_contrato, fecha_de_fin_del_contrato,
       fecha_inicio_liquidacion, fecha_fin_liquidacion,
       fecha_de_notificaci_n_de_prorrogaci_n, ultima_actualizacion
"""
results = client.get("jbjy-vk9h", query=query)

dim_tiempo = pd.DataFrame.from_records(results)

dim_tiempo = dim_tiempo[[
     "fecha_de_firma", "fecha_de_inicio_del_contrato",
    "fecha_de_fin_del_contrato", "fecha_inicio_liquidacion",
    "fecha_fin_liquidacion", "fecha_de_notificaci_n_de_prorrogaci_n",
    "ultima_actualizacion"
]]

dim_tiempo.head()
# Out:
#    id_tiempo           fecha_de_firma fecha_de_inicio_del_contrato  \
# 0          1  2015-06-11T00:00:00.000      2015-06-11T00:00:00.000
# 1          2  2015-07-07T00:00:00.000      2015-07-08T00:00:00.000
# 2          3  2015-09-09T00:00:00.000      2015-09-11T00:00:00.000
# 3          4  2015-09-10T00:00:00.000      2015-09-10T00:00:00.000
# 4          5  2015-11-18T00:00:00.000      2015-11-18T00:00:00.000
#
#   fecha_de_fin_del_contrato fecha_inicio_liquidacion fecha_fin_liquidacion  \
# 0   2015-12-31T00:00:00.000                      NaN                   NaN
# 1   2015-07-17T00:00:00.000                      NaN                   NaN
# 2   2015-12-31T00:00:00.000                      NaN                   NaN
# 3   2015-12-31T00:00:00.000                      NaN                   NaN
# 4   2015-12-31T00:00:00.000                      NaN                   NaN
#
#   fecha_de_notificaci_n_de_prorrogaci_n ultima_actualizacion
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2               2016-01-01T00:00:00.000                  NaN
# 3                                   NaN                  NaN
# 4               2016-01-01T00:00:00.000                  NaN

# %%
query = """
SELECT DISTINCT estado_contrato, liquidaci_n, habilita_pago_adelantado, el_contrato_puede_ser_prorrogado
"""
results = client.get("jbjy-vk9h", query=query)

dim_estado_contrato = pd.DataFrame.from_records(results)

dim_estado_contrato = dim_estado_contrato[[
    "estado_contrato", "liquidaci_n",
    "habilita_pago_adelantado", "el_contrato_puede_ser_prorrogado"
]]

dim_estado_contrato.head()
# Out:
#   estado_contrato liquidaci_n habilita_pago_adelantado  \
# 0      Suspendido          Si              No Definido
# 1   En aprobación          No              No Definido
# 2      Modificado          No              No Definido
# 3          cedido          No              No Definido
# 4          cedido          No                       No
#
#   el_contrato_puede_ser_prorrogado
# 0                               Si
# 1                               Si
# 2                               No
# 3                               Si
# 4                               Si

# %%
query = """
SELECT DISTINCT origen_de_los_recursos, destino_gasto
"""
results = client.get("jbjy-vk9h", query=query)

dim_recursos_financieros = pd.DataFrame.from_records(results)

dim_recursos_financieros = dim_recursos_financieros[[
     "origen_de_los_recursos", "destino_gasto"
]]

dim_recursos_financieros.head()
# Out:
#   origen_de_los_recursos   destino_gasto
# 0            Distribuido       Inversión
# 1            Distribuido     No Definido
# 2       Recursos Propios  Funcionamiento
# 3            Distribuido  Funcionamiento
# 4       Recursos Propios     No Definido

# %%
query = """
SELECT DISTINCT espostconflicto, obligaci_n_ambiental, obligaciones_postconsumo,
       reversion, puntos_del_acuerdo, pilares_del_acuerdo, estado_bpin
"""
results = client.get("jbjy-vk9h", query=query)

dim_marcadores = pd.DataFrame.from_records(results)

dim_marcadores = dim_marcadores[[
     "espostconflicto", "obligaci_n_ambiental",
    "obligaciones_postconsumo", "reversion",
    "puntos_del_acuerdo", "pilares_del_acuerdo", "estado_bpin"
]]

dim_marcadores.head()
# Out:
#   espostconflicto obligaci_n_ambiental obligaciones_postconsumo reversion  \
# 0              No                   No                       No        No
# 1              No                   No                       No        No
# 2              No                   No                       No        No
# 3              No                   No                       No        No
# 4              No                   No                       No        No
#
#        puntos_del_acuerdo pilares_del_acuerdo estado_bpin
# 0               No aplica           No aplica   No Válido
# 1               No aplica           No aplica      Válido
# 2    ReformaRuralIntegral    DSEducationRural   No Válido
# 3  SolucionProblemaDrogas                PCSP      Válido
# 4                      TG      CapituloGenero   No Válido

# %%
query = """
SELECT DISTINCT nombre_ordenador_del_gasto, tipo_de_documento_ordenador_del_gasto,
       n_mero_de_documento_ordenador_del_gasto, nombre_supervisor,
       tipo_de_documento_supervisor, n_mero_de_documento_supervisor,
       nombre_ordenador_de_pago, tipo_de_documento_ordenador_de_pago,
       n_mero_de_documento_ordenador_de_pago, nombre_representante_legal,
       tipo_de_identificaci_n_representante_legal, identificaci_n_representante_legal,
       nacionalidad_representante_legal, domicilio_representante_legal, g_nero_representante_legal
"""
results = client.get("jbjy-vk9h", query=query)

dim_responsables = pd.DataFrame.from_records(results)

dim_responsables = dim_responsables[[
    "nombre_ordenador_del_gasto",
    "tipo_de_documento_ordenador_del_gasto", "n_mero_de_documento_ordenador_del_gasto",
    "nombre_supervisor", "tipo_de_documento_supervisor", "n_mero_de_documento_supervisor",
    "nombre_ordenador_de_pago", "tipo_de_documento_ordenador_de_pago", "n_mero_de_documento_ordenador_de_pago",
    "nombre_representante_legal", "tipo_de_identificaci_n_representante_legal",
    "identificaci_n_representante_legal", "nacionalidad_representante_legal",
    "domicilio_representante_legal", "g_nero_representante_legal"
]]

dim_responsables.head()
# Out:
#       nombre_ordenador_del_gasto tipo_de_documento_ordenador_del_gasto  \
# 0      1 MARGARITA OSPINA GUZMAN                  Cédula de Ciudadanía
# 1      1 MARGARITA OSPINA GUZMAN                  Cédula de Ciudadanía
# 2           AALVARO ROJAS TOLOZA                  Cédula de Ciudadanía
# 3  ABDUL ANTONIO SOLORZANO AVILA                  Cédula de Ciudadanía
# 4  ABDUL ANTONIO SOLORZANO AVILA                  Cédula de Ciudadanía
#
#   n_mero_de_documento_ordenador_del_gasto              nombre_supervisor  \
# 0                              1054992672           KATHERINE SOTO DUQUE
# 1                              1054992672       MANUEL FELIPE LOPEZ NOVA
# 2                                 5688614                    No definido
# 3                                16446319  ABDUL ANTONIO SOLORZANO AVILA
# 4                                16446319  ABDUL ANTONIO SOLORZANO AVILA
#
#   tipo_de_documento_supervisor n_mero_de_documento_supervisor  \
# 0         Cédula de Ciudadanía                  1.053.819.210
# 1         Cédula de Ciudadanía                     1053838043
# 2                  No definido                    No definido
# 3         Cédula de Ciudadanía                       16446319
# 4         Cédula de Ciudadanía                       16446319
#
#   nombre_ordenador_de_pago tipo_de_documento_ordenador_de_pago  \
# 0              No definido                         No definido
# 1              No definido                         No definido
# 2              No definido                         No definido
# 3              No definido                         No definido
# 4              No definido                         No definido
#
#   n_mero_de_documento_ordenador_de_pago  \
# 0                           No definido
# 1                           No definido
# 2                           No definido
# 3                           No definido
# 4                           No definido
#
#                 nombre_representante_legal  \
# 0             JUAN JOSE QUINTERO SUCERQUIA
# 1                     FABIO SALAZAR TAMAYO
# 2                     Lidman Alirio Jaimes
# 3  HENRY VARELA CIFUENTES VARELA CIFUENTES
# 4             JAIRO GIOVANNI BARRERA ADAME
#
#   tipo_de_identificaci_n_representante_legal  \
# 0                            Sin Descripcion
# 1                            Sin Descripcion
# 2                       Cédula de Ciudadanía
# 3                       Cédula de Ciudadanía
# 4                            Sin Descripcion
#
#   identificaci_n_representante_legal nacionalidad_representante_legal  \
# 0                    Sin Descripcion                               CO
# 1                    Sin Descripcion                               CO
# 2                           91235155                               CO
# 3                            6288664                               CO
# 4                    Sin Descripcion                               CO
#
#   domicilio_representante_legal g_nero_representante_legal
# 0                   No Definido                     Hombre
# 1                   No Definido                     Hombre
# 2                   No Definido                      Mujer
# 3              CALLE 7 N° 13-17                     Hombre
# 4                   No Definido                     Hombre

# %%
query = """
SELECT DISTINCT nombre_del_banco, tipo_de_cuenta, n_mero_de_cuenta
"""
results = client.get("jbjy-vk9h", query=query)

dim_cuentas = pd.DataFrame.from_records(results)

dim_cuentas = dim_cuentas[[
    "nombre_del_banco", "tipo_de_cuenta", "n_mero_de_cuenta"
]]

dim_cuentas.head(50)
# Out:
#            nombre_del_banco tipo_de_cuenta     n_mero_de_cuenta
# 0                         |    No Definido          No definido
# 1                         -    No Definido                  NaN
# 2                         ¡    No Definido          No definido
# 3    ??????????????????????        Ahorros          03193839648
# 4    ??????????????????????        Ahorros          04040450136
# 5                         ¿        Ahorros          No definido
# 6                         .        Ahorros                00000
# 7                         .        Ahorros                    1
# 8                         .        Ahorros                  NaN
# 9                         .    No Definido          No definido
# 10                        }    No Definido          No definido
# 11                        *        Ahorros                    *
# 12                   ******        Ahorros               ******
# 13           **************        Ahorros      ***************
# 14                        +    No Definido          No definido
# 15             ++++++++++++    No Definido        +++++++++++++
# 16                        0        Ahorros                    0
# 17                        0      Corriente                    0
# 18                        0    No Definido                    0
# 19                        0    No Definido          No definido
# 20                       00        Ahorros                   00
# 21                       00    No Definido                   00
# 22                      000        Ahorros                  000
# 23                      000    No Definido                  000
# 24                     0000        Ahorros                  000
# 25                     0000        Ahorros                 0000
# 26                     0000      Corriente                 0000
# 27                   000000        Ahorros                00000
# 28                   000000        Ahorros               000000
# 29                   000000    No Definido           0000000000
# 30                  0000000        Ahorros              0000000
# 31                 00000000    No Definido               000000
# 32               0000000000        Ahorros           0000000000
# 33              00000000000        Ahorros           0000000000
# 34        00000000000000000        Ahorros         000000000000
# 35         0000008970190388        Ahorros      BancoDavivienda
# 36             000042063156      Corriente           DAVIVIENDA
# 37           00018252323316        Ahorros           DAVIVIENDA
# 38             000210007498      Corriente      BANCODAVIVIENDA
# 39             000500089636        Ahorros           DAVIVIENDA
# 40             000502018988        Ahorros  SCOTIABANKCOLPATRIA
# 41             000570106138        Ahorros           davivienda
# 42             000570112821        Ahorros           davivienda
# 43           0005 7012 1343        Ahorros           DAVIVIENDA
# 44             000970164158        Ahorros           DAVIVIENDA
# 45             001160017685      Corriente      BaconDavivienda
# 46  0013-0042-00-0200286856        Ahorros                 BBVA
# 47     00130090000200329293        Ahorros                 BBVA
# 48     00130331000200036905        Ahorros                 BBVA
# 49     00130440000200336071        Ahorros                 BBVA

# %%
query = """
SELECT DISTINCT proceso_de_compra, descripcion_del_proceso, objeto_del_contrato,
       condiciones_de_entrega, urlproceso, referencia_del_contrato
"""
results = client.get("jbjy-vk9h", query=query)

dim_proceso = pd.DataFrame.from_records(results)

dim_proceso = dim_proceso[[
     "proceso_de_compra", "descripcion_del_proceso",
    "objeto_del_contrato", "condiciones_de_entrega", "referencia_del_contrato"
]]

dim_proceso.head()
# Out:
#   proceso_de_compra                            descripcion_del_proceso  \
# 0  CO1.BDOS.1000010  Suministrar la dotación de Ley; CALZADO PARA D...
# 1  CO1.BDOS.1000011  LA ADQUISICIÓN DE MATERIAL VETERINARIO PARA LO...
# 2  CO1.BDOS.1000012  Prestar servicios profesionales para apoyar en...
# 3  CO1.BDOS.1000014  Prestar servicios profesionales para apoyar en...
# 4  CO1.BDOS.1000015  CONTRATAR LA ADQUISICIÓN DE LLANTAS; INCLUYEND...
#
#                                  objeto_del_contrato  \
# 0  Suministrar la dotación de Ley; CALZADO PARA D...
# 1  LA ADQUISICIÓN DE MATERIAL VETERINARIO PARA LO...
# 2  Prestar servicios profesionales para apoyar en...
# 3  Prestar servicios profesionales para apoyar en...
# 4  CONTRATAR LA ADQUISICIÓN DE LLANTAS; INCLUYEND...
#
#       condiciones_de_entrega referencia_del_contrato
# 0                No Definido                 3531/19
# 1  Como acordado previamente    067-CENACIBAGUE-2019
# 2  Como acordado previamente         CPS 104 DE 2020
# 3  Como acordado previamente         CPS 102 DE 2020
# 4                 A convenir            CTO-546-2019
